# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import keras
import pandas as pd
from keras.layers import Dense, Activation, Dropout
from keras.models import Sequential
from keras.utils import np_utils
from sklearn import preprocessing

# %%
df = pd.read_csv('/home/sharad/CodingBlocksPython/Mushroom/mushrooms.csv')
print df.shape
df.info()
# Out:
# (8124, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
# class                       8124 non-null object
# cap-shape                   8124 non-null object
# cap-surface                 8124 non-null object
# cap-color                   8124 non-null object
# bruises                     8124 non-null object
# odor                        8124 non-null object
# gill-attachment             8124 non-null object
# gill-spacing                8124 non-null object
# gill-size                   8124 non-null object
# gill-color                  8124 non-null object
# stalk-shape                 8124 non-null object
# stalk-root                  8124 non-null object
# stalk-surface-above-ring    8124 non-null object
# stalk-surface-below-ring    8124 non-null object
# stalk-color-above-ring      8124 non-null object
# stalk-color-below-ring      8124 non-null object
# veil-type                   8124 non-null object
# veil-color                  8124 non-null object
# ring-number                 8124 non-null object
# ring-type                   8124 non-null object
# spore-print-color           8124 non-null object
# population                  8124 non-null object
# habitat                     8124 non-null object
# dtypes: object(23)
# memory usage: 1.4+ MB

# %%
labelEncoder = preprocessing.LabelEncoder()
for col in df.columns:
    df[col] = labelEncoder.fit_transform(df[col])
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color   ...     stalk-surface-below-ring  \
# 0             0          1           4   ...                            2
# 1             0          0           4   ...                            2
# 2             0          0           5   ...                            2
# 3             0          1           5   ...                            2
# 4             1          0           4   ...                            2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
model = Sequential()

model.add(Dense(512, input_shape=(22,)))
model.add(Activation('relu'))
model.add(Dropout(0.50))

model.add(Dense(180))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(2))
model.add(Activation('softmax'))

model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               11776
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 180)               92340
# _________________________________________________________________
# activation_2 (Activation)    (None, 180)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 180)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 362
# _________________________________________________________________
# activation_3 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 104,478
# Trainable params: 104,478
# Non-trainable params: 0
# _________________________________________________________________

# %%
data = df.values
data.shape
X = data[:,1:]
X.shape
Y = np_utils.to_categorical(data[:,0])
Y.shape
# Out:
# (8124, 2)

# %%
hist = model.fit(X, Y,
                epochs=50,
                shuffle=True,
                batch_size=100)
                #validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 8124/8124 [==============================] - 1s - loss: 0.3900 - acc: 0.8368
# Epoch 2/50
# 8124/8124 [==============================] - 0s - loss: 0.1750 - acc: 0.9323
# Epoch 3/50
# 8124/8124 [==============================] - 0s - loss: 0.0912 - acc: 0.9674
# Epoch 4/50
# 8124/8124 [==============================] - 0s - loss: 0.0493 - acc: 0.9835
# Epoch 5/50
# 8124/8124 [==============================] - 0s - loss: 0.0335 - acc: 0.9882
# Epoch 6/50
# 8124/8124 [==============================] - 0s - loss: 0.0213 - acc: 0.9929
# Epoch 7/50
# 8124/8124 [==============================] - 0s - loss: 0.0174 - acc: 0.9941
# Epoch 8/50
# 8124/8124 [==============================] - 0s - loss: 0.0157 - acc: 0.9951
# Epoch 9/50
# 8124/8124 [==============================] - 0s - loss: 0.0148 - acc: 0.9940
# Epoch 10/50
# 8124/8124 [==============================] - 1s - loss: 0.0093 - acc: 0.9977
# Epoch 11/50
# 8124/8124 [==============================] - 1s - loss: 0.0072 - acc: 0.9979
# Epoch 12/50
# 8124/8124 [==============================] - 1s - loss: 0.0067 - acc: 0.9979
# Epoch 13/50
# 8124/8124 [==============================] - 1s - loss: 0.0083 - acc: 0.9974
# Epoch 14/50
# 8124/8124 [==============================] - 0s - loss: 0.0059 - acc: 0.9984
# Epoch 15/50
# 8124/8124 [==============================] - 0s - loss: 0.0098 - acc: 0.9962
# Epoch 16/50
# 8124/8124 [==============================] - 1s - loss: 0.0051 - acc: 0.9985
# Epoch 17/50
# 8124/8124 [==============================] - 0s - loss: 0.0042 - acc: 0.9985
# Epoch 18/50
# 8124/8124 [==============================] - 1s - loss: 0.0024 - acc: 0.9993
# Epoch 19/50
# 8124/8124 [==============================] - 0s - loss: 0.0043 - acc: 0.9985
# Epoch 20/50
# 8124/8124 [==============================] - 1s - loss: 0.0057 - acc: 0.9984
# Epoch 21/50
# 8124/8124 [==============================] - 1s - loss: 0.0063 - acc: 0.9982
# Epoch 22/50
# 8124/8124 [==============================] - 1s - loss: 0.0058 - acc: 0.9980
# Epoch 23/50
# 8124/8124 [==============================] - 1s - loss: 0.0043 - acc: 0.9986
# Epoch 24/50
# 8124/8124 [==============================] - 0s - loss: 0.0040 - acc: 0.9984
# Epoch 25/50
# 8124/8124 [==============================] - 1s - loss: 0.0076 - acc: 0.9969
# Epoch 26/50
# 8124/8124 [==============================] - 1s - loss: 0.0065 - acc: 0.9980
# Epoch 27/50
# 8124/8124 [==============================] - 1s - loss: 0.0041 - acc: 0.9988
# Epoch 28/50
# 8124/8124 [==============================] - 0s - loss: 0.0037 - acc: 0.9985
# Epoch 29/50
# 8124/8124 [==============================] - 0s - loss: 0.0049 - acc: 0.9986
# Epoch 30/50
# 8124/8124 [==============================] - 1s - loss: 0.0031 - acc: 0.9989
# Epoch 31/50
# 8124/8124 [==============================] - 1s - loss: 0.0030 - acc: 0.9991
# Epoch 32/50
# 8124/8124 [==============================] - 1s - loss: 0.0045 - acc: 0.9985
# Epoch 33/50
# 8124/8124 [==============================] - 1s - loss: 0.0040 - acc: 0.9985
# Epoch 34/50
# 8124/8124 [==============================] - 0s - loss: 0.0048 - acc: 0.9982
# Epoch 35/50
# 8124/8124 [==============================] - 0s - loss: 0.0049 - acc: 0.9979
# Epoch 36/50
# 8124/8124 [==============================] - 1s - loss: 0.0050 - acc: 0.9985
# Epoch 37/50
# 8124/8124 [==============================] - 1s - loss: 0.0055 - acc: 0.9983
# Epoch 38/50
# 8124/8124 [==============================] - 0s - loss: 0.0051 - acc: 0.9984
# Epoch 39/50
# 8124/8124 [==============================] - 1s - loss: 0.0041 - acc: 0.9986
# Epoch 40/50
# 8124/8124 [==============================] - 0s - loss: 0.0024 - acc: 0.9993
# Epoch 41/50
# 8124/8124 [==============================] - 1s - loss: 0.0023 - acc: 0.9991
# Epoch 42/50
# 8124/8124 [==============================] - 1s - loss: 0.0025 - acc: 0.9991
# Epoch 43/50
# 8124/8124 [==============================] - 0s - loss: 0.0030 - acc: 0.9989
# Epoch 44/50
# 8124/8124 [==============================] - 1s - loss: 0.0055 - acc: 0.9977     - ETA: 1s - loss: 0.0
# Epoch 45/50
# 8124/8124 [==============================] - 1s - loss: 0.0049 - acc: 0.9978
# Epoch 46/50
# 8124/8124 [==============================] - 1s - loss: 0.0024 - acc: 0.9993
# Epoch 47/50
# 8124/8124 [==============================] - 1s - loss: 0.0027 - acc: 0.9989
# Epoch 48/50
# 8124/8124 [==============================] - 1s - loss: 0.0044 - acc: 0.9985
# Epoch 49/50
# 8124/8124 [==============================] - 1s - loss: 0.0015 - acc: 0.9996
# Epoch 50/50
# 8124/8124 [==============================] - 1s - loss: 0.0032 - acc: 0.9988
